# %% [markdown]
# # Simple noise analysis

# %% [markdown]
# Calculate PSD, PGV, PGA and PMS per day and save these parameters as a numpy array.
#
# Create some simple plots.

# %%
import numpy as np
import pandas as pd
import obspy
import obspy.signal.filter
from pnwstore.mseed import WaveformClient
client = WaveformClient()
import datetime
import datetime
import scipy
import glob
import sys
import os
import math
import matplotlib.pyplot as plt
import matplotlib

# %%
sys.path.append('/home/koepflma/project1/')
from functions import *

# %%
# read data to stream
net = 'UW'
sta = 'EDM'
cha = 'EHZ'
year = 2020
jday = 102
st_r = read_stream(net, sta, cha, year, jday)
st_r
# Out:
# 2 Trace(s) in Stream:
# UW.EDM..EHZ | 2020-04-11T00:00:00.000001Z - 2020-04-11T19:53:30.260001Z | 100.0 Hz, 7161027 samples
# UW.EDM..EHZ | 2020-04-11T19:53:31.711477Z - 2020-04-11T23:59:59.901477Z | 100.0 Hz, 1478820 samples

# %%
tr_Test = st_r[0].data.copy()
plt.plot(tr_Test)
max(tr_Test)
# Out:
# 1355

# %%
tr_TEST = tr_Test.data/2.9964E8
plt.plot(tr_TEST)
max(tr_TEST)
# Out:
# 4.5220931784808436e-06

# %%
inv = obspy.read_inventory('/auto/pnwstore1-wd11/PNWStationXML/UW/UW.EDM.xml')
pre_filt = [1e-5, 5e-5, 45, 50]
water_level = 10
st = st_r.copy()
for tr in st:
    tr.plot()
    tr.remove_response(inventory=inv, zero_mean=True,taper=True, taper_fraction=0.05,
                          pre_filt=pre_filt, output="VEL", water_level=water_level,
                          plot=True)
#                           plot='sensor_response_tests/{}_pre_filt{}-{}_{}-{}__water_level{}.png'.format(
#                           tr.stats['starttime'],
#                           pre_filt[0], pre_filt[1], pre_filt[2], pre_filt[3], water_level))

# %%
# # detrend and taper
# st = st_r.copy()
# st.detrend('demean')
# #st.taper(max_percentage=0.05, type='hann')
# st.taper(0.05)
# st = st.merge()

# %%
# define window length and window overlap
#win_len = 60*60*24 * st[0].stats.sampling_rate # points per day
win_len = 2**14 # number of points in window
win_overlap = 0 # number of overlapping points

# %%
# calculate PSD
for tr in st:
    npts_st += tr.stats['ntps']
# for tr in st:
Pxx, freqs = matplotlib.mlab.psd(st[0].data, NFFT=win_len, noverlap=win_overlap, Fs=st[0].stats.sampling_rate)
# add a weight to trace

print(Pxx.shape, freqs.shape)
# Out:
# (8193,) (8193,)

# %%
ntps_st = 0
for tr in st:
    npts_st += tr.stats['ntps']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [25], in <module>
#       1 ntps_st = 0
#       2 for tr in st:
# ----> 3     npts_st += tr.stats['ntps']
#
# NameError: name 'npts_st' is not defined

# %%
# 2**14 day instrument response removed
fig, ax = plt.subplots()
ax.plot(freqs, Pxx)
#ax.set_xlim(5e-2,3e1)
#ax.set_ylim(1e-15,1e-10)
ax.set_xscale('log')
ax.set_yscale('log')

# %% [markdown]
# produce start times depending on window length and overlap
#
# loop over starttime -> segment should have win_length

# %%
start_sec = np.arange(0, st[0].stats['npts'],
                  math.floor((st[0].stats['npts']*st[0].stats['delta'])/(win_len-win_overlap))) # start, stop, step

#  5898240 5914624 5931008 5947392 5963776 5980160 5996544 6012928 6029312
#  6045696 6062080 6078464 6094848 6111232 6127616 6144000 6160384 6176768
#  6193152 6209536 6225920 6242304 6258688 6275072 6291456 6307840 6324224
#  6340608 6356992 6373376 6389760 6406144 6422528 6438912 6455296 6471680
#  6488064 6504448 6520832 6537216 6553600 6569984 6586368 6602752 6619136
#  6635520 6651904 6668288 6684672 6701056 6717440 6733824 6750208 6766592
#  6782976 6799360 6815744 6832128 6848512 6864896 6881280 6897664 6914048
#  6930432 6946816 6963200 6979584 6995968 7012352 7028736 7045120 7061504
#  7077888 7094272 7110656 7127040 7143424 7159808] (438,)

# %%
tr_test = st[0].data[start_points[0]:start_points[1]] # tr does not include the point at start_sec[1]
tr_test_rms = np.sqrt(np.mean(tr_test**2))
tr_test_pgv = max(abs(tr_test))
print(tr_test_rms,tr_test_pgv)
# Out:
# 1.0979248605535974e-08 6.510579158584795e-08

# %%
tr_acc_test1 = tr_test.copy()[:-1] 
tr_acc_test2 = tr_test.copy()[1:]
tr_acc_test_diff = tr_acc_test1-tr_acc_test2
tr_acc_test = tr_acc_test_diff/st[0].stats['delta'] # 'delta': 1/sampling_rate -> time in sec between points
tr_test_pga = max(abs(tr_acc_test))
print(tr_test_pga)
# Out:
# 5.9752766412937905e-06

# %% [markdown]
# ### calculate RMS, PGV, PGA
# windwow_values **2
# sum over window length
# devide trough window length
# take sqrt
# #rms = np.std()
#
# take max vel
#
# ableiten
# take max acc

# %%
# 1 day taper 0.0045
fig, ax = plt.subplots()
ax.plot(freqs, Pxx)
ax.set_xlim(5e-2,3e1)
ax.set_xscale('log')
ax.set_yscale('log')

# %%
# 1 day taper 0.45
fig, ax = plt.subplots()
ax.plot(freqs, Pxx)
ax.set_xlim(5e-2,3e1)
ax.set_xscale('log')
ax.set_yscale('log')

# %%
# 2**14 taper 0.0045
fig, ax = plt.subplots()
ax.plot(freqs, Pxx)
ax.set_xlim(1e-1,3e1)
ax.set_xscale('log')
ax.set_yscale('log')

# %%
# 2**10 taper 0.45
fig, ax = plt.subplots()
ax.plot(freqs, Pxx)
ax.set_xlim(1e-1,3e1)
ax.set_xscale('log')
ax.set_yscale('log')

# %%
xx_arr = np.array([1,3,5,7])
xx_arr
# Out:
# array([1, 3, 5, 7])

# %%
test_npa = np.array([Pxx, freqs, xx_arr])
test_npa.shape
# Out:
# (3,)

# %%
save_path = 'first_test'
save_filename = '{}_{}_{}'.format(year, jday, sta)
nparray = test_npa

# %%
save_nparray(save_path, save_filename, nparray)
# Out:
# 2020_100_EDM done

# %%
test_load= np.load('{}/{}.npy'.format(save_path, save_filename), allow_pickle=True)
test_load
# Out:
# array([array([2.43656405e+04, 1.21786106e+04, 4.03639762e+01, ...,
#               1.29934869e-01, 1.23227801e-01, 5.96165319e-02])    ,
#        array([0.00000000e+00, 2.44140625e-02, 4.88281250e-02, ...,
#               4.99511719e+01, 4.99755859e+01, 5.00000000e+01])    ,
#        array([1, 3, 5, 7])], dtype=object)
